# %% [markdown]
# # Rating

# %%
import pandas as pd
import missingno as msno
import numpy as np

# %%
rating = pd.read_csv(r"../data/rating.csv")

# %%
rating.columns = rating.columns.str.lower() # en minuscular
rating.columns = rating.columns.str.strip() # quitar espacios en blanco
rating.head()
# Out:
#    userid  movieid  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
# Total de registros
len(rating)
# Out:
# 20000263

# %%
# Verificamos que no haya nulos
rating.isna().sum()
# Out:
# userid       0
# movieid      0
# rating       0
# timestamp    0
# dtype: int64

# %%
# Cambiar el tipo de datos `object` de timestamp a datetime
rating["timestamp"] = pd.to_datetime(rating["timestamp"])

# %%
rating.head()
# Out:
#    userid  movieid  rating           timestamp
# 0       1        2     3.5 2005-04-02 23:53:47
# 1       1       29     3.5 2005-04-02 23:31:16
# 2       1       32     3.5 2005-04-02 23:33:39
# 3       1       47     3.5 2005-04-02 23:32:07
# 4       1       50     3.5 2005-04-02 23:29:40

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000263 entries, 0 to 20000262
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   userid     int64
#  1   movieid    int64
#  2   rating     float64
#  3   timestamp  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(2)
# memory usage: 610.4 MB

# %%
# Adicionamos la columna `year` y llenar con el año del timestamp
rating["year"] =  rating['timestamp'].dt.year
rating["month"] =  rating['timestamp'].dt.month
rating.head()
# Out:
#    userid  movieid  rating           timestamp  year  month
# 0       1        2     3.5 2005-04-02 23:53:47  2005      4
# 1       1       29     3.5 2005-04-02 23:31:16  2005      4
# 2       1       32     3.5 2005-04-02 23:33:39  2005      4
# 3       1       47     3.5 2005-04-02 23:32:07  2005      4
# 4       1       50     3.5 2005-04-02 23:29:40  2005      4

# %% [markdown]
# # DATA OPCION 1
#
# Promedio y conteo en forma general agrupado unicamente por movieid

# %%
# Obtenemos el rating promedio y el conteo general 
rating_movies_promedio = rating.groupby(["movieid"])["rating"].mean()
rating_movies_conteo = rating.groupby(["movieid"])["rating"].count()

# %%
# Promedio de rating por pelicula de forma global en todos los años
rating_movies_promedio.head()
# Out:
# movieid
# 1    3.921240
# 2    3.211977
# 3    3.151040
# 4    2.861393
# 5    3.064592
# Name: rating, dtype: float64

# %%
# Conteo de rating por pelicula de forma global en todos los años
rating_movies_conteo.head()
# Out:
# movieid
# 1    49695
# 2    22243
# 3    12735
# 4     2756
# 5    12161
# Name: rating, dtype: int64

# %%
# union de promeido y conteo
rating_promedio_conteo = pd.merge(rating_movies_promedio, rating_movies_conteo, on="movieid", how="left")

# %%
rating_promedio_conteo.head()
# Out:
#          rating_x  rating_y
# movieid
# 1        3.921240     49695
# 2        3.211977     22243
# 3        3.151040     12735
# 4        2.861393      2756
# 5        3.064592     12161

# %%
# renombrar columnas
rating_promedio_conteo = rating_promedio_conteo.rename(
    columns={
        "rating_x": "rating_promedio",
        "rating_y": "rating_conteo"
    }
)

# %%
rating_promedio_conteo.head()
# Out:
#          rating_promedio  rating_conteo
# movieid
# 1               3.921240          49695
# 2               3.211977          22243
# 3               3.151040          12735
# 4               2.861393           2756
# 5               3.064592          12161

# %%
# Es el total de registros
rating_promedio_conteo["rating_conteo"].sum()
# Esta OK
# Out:
# np.int64(20000263)

# %%
rating_promedio_conteo.head()
# Out:
#          rating_promedio  rating_conteo
# movieid
# 1               3.921240          49695
# 2               3.211977          22243
# 3               3.151040          12735
# 4               2.861393           2756
# 5               3.064592          12161

# %%
# Guardado de tabla dimension usuarios temporal
rating_promedio_conteo.to_csv(r"../data/partial_rating.csv")

# %% [markdown]
# # DATA OPCION 2
# Promedio agrupado por movieid y year
# Se procede a crear una tabla que las columnas sean los años y ahi el promedio
# Resultado -> archivo tipo insumo para tabla de hecho `partial_rating_year.csv`

# %%
df_year_promedio = rating.groupby(["movieid","year"]).agg({"rating": "mean"})

# %%
# df_year_promedio.reset_index(inplace=True)
# df_year_promedio.set_index("movieid", inplace=True)
df_year_promedio
# Out:
#          year    rating
# movieid
# 1        1996  4.132270
# 1        1997  3.875424
# 1        1998  3.885799
# 1        1999  3.974688
# 1        2000  4.142609
# ...       ...       ...
# 131254   2015  4.000000
# 131256   2015  4.000000
# 131258   2015  2.500000
# 131260   2015  3.000000
# 131262   2015  4.000000
#
# [178385 rows x 2 columns]

# %%
type(df_year_promedio)
# Out:
# pandas.core.frame.DataFrame

# %%
df_pivot = df_year_promedio.pivot(columns='year', values=['rating'])

# %%
df_pivot.head()
# Out:
#         rating                                                              \
# year      1995      1996      1997      1998      1999      2000      2001
# movieid
# 1          NaN  4.132270  3.875424  3.885799  3.974688  4.142609  4.117698
# 2          NaN  3.564570  3.457698  3.263158  3.139094  3.146533  3.136856
# 3          NaN  3.413843  3.291299  3.102990  2.930788  3.024691  3.204023
# 4          NaN  3.030162  3.057803  2.590909  2.710000  2.744382  2.755906
# 5          NaN  3.338714  3.114710  3.090909  3.070922  2.934859  3.100000
#
#                                        ...                                \
# year         2002      2003      2004  ...      2006      2007      2008
# movieid                                ...
# 1        4.047855  4.004680  3.863380  ...  3.680774  3.672973  3.740781
# 2        3.077821  2.956271  2.887043  ...  2.876154  2.923704  3.059659
# 3        3.021552  2.957346  2.920536  ...  2.758454  2.990909  3.112245
# 4        2.836735  2.564103  2.585859  ...  2.531250  2.310811  2.523810
# 5        3.004651  2.803867  2.797483  ...  2.765337  2.633333  2.725849
#
#
# year         2009      2010      2011      2012      2013      2014      2015
# movieid
# 1        3.766777  3.856772  3.861689  3.931421  3.946274  3.954945  3.860412
# 2        3.044865  3.159884  3.178733  3.201903  3.266667  3.346552  3.128049
# 3        3.102837  2.986364  3.051724  2.799451  3.064103  3.048387  2.854167
# 4        2.500000  2.833333  2.944444  2.545455  3.187500  2.357143  2.000000
# 5        2.864662  2.812500  2.913462  2.609804  2.770936  2.897059  2.842105
#
# [5 rows x 21 columns]

# %%
df_pivot = df_pivot.replace(np.nan, 0)

# %%
df_pivot.head()
# Out:
#         rating                                                              \
# year      1995      1996      1997      1998      1999      2000      2001
# movieid
# 1          0.0  4.132270  3.875424  3.885799  3.974688  4.142609  4.117698
# 2          0.0  3.564570  3.457698  3.263158  3.139094  3.146533  3.136856
# 3          0.0  3.413843  3.291299  3.102990  2.930788  3.024691  3.204023
# 4          0.0  3.030162  3.057803  2.590909  2.710000  2.744382  2.755906
# 5          0.0  3.338714  3.114710  3.090909  3.070922  2.934859  3.100000
#
#                                        ...                                \
# year         2002      2003      2004  ...      2006      2007      2008
# movieid                                ...
# 1        4.047855  4.004680  3.863380  ...  3.680774  3.672973  3.740781
# 2        3.077821  2.956271  2.887043  ...  2.876154  2.923704  3.059659
# 3        3.021552  2.957346  2.920536  ...  2.758454  2.990909  3.112245
# 4        2.836735  2.564103  2.585859  ...  2.531250  2.310811  2.523810
# 5        3.004651  2.803867  2.797483  ...  2.765337  2.633333  2.725849
#
#
# year         2009      2010      2011      2012      2013      2014      2015
# movieid
# 1        3.766777  3.856772  3.861689  3.931421  3.946274  3.954945  3.860412
# 2        3.044865  3.159884  3.178733  3.201903  3.266667  3.346552  3.128049
# 3        3.102837  2.986364  3.051724  2.799451  3.064103  3.048387  2.854167
# 4        2.500000  2.833333  2.944444  2.545455  3.187500  2.357143  2.000000
# 5        2.864662  2.812500  2.913462  2.609804  2.770936  2.897059  2.842105
#
# [5 rows x 21 columns]

# %%
type(df_pivot)
# Out:
# pandas.core.frame.DataFrame

# %%
df_pivot = df_pivot.reset_index()

# %%
df_pivot.head()
# Out:
#      movieid rating                                                    \
# year           1995      1996      1997      1998      1999      2000
# 0          1    0.0  4.132270  3.875424  3.885799  3.974688  4.142609
# 1          2    0.0  3.564570  3.457698  3.263158  3.139094  3.146533
# 2          3    0.0  3.413843  3.291299  3.102990  2.930788  3.024691
# 3          4    0.0  3.030162  3.057803  2.590909  2.710000  2.744382
# 4          5    0.0  3.338714  3.114710  3.090909  3.070922  2.934859
#
#                                     ...                                \
# year      2001      2002      2003  ...      2006      2007      2008
# 0     4.117698  4.047855  4.004680  ...  3.680774  3.672973  3.740781
# 1     3.136856  3.077821  2.956271  ...  2.876154  2.923704  3.059659
# 2     3.204023  3.021552  2.957346  ...  2.758454  2.990909  3.112245
# 3     2.755906  2.836735  2.564103  ...  2.531250  2.310811  2.523810
# 4     3.100000  3.004651  2.803867  ...  2.765337  2.633333  2.725849
#
#
# year      2009      2010      2011      2012      2013      2014      2015
# 0     3.766777  3.856772  3.861689  3.931421  3.946274  3.954945  3.860412
# 1     3.044865  3.159884  3.178733  3.201903  3.266667  3.346552  3.128049
# 2     3.102837  2.986364  3.051724  2.799451  3.064103  3.048387  2.854167
# 3     2.500000  2.833333  2.944444  2.545455  3.187500  2.357143  2.000000
# 4     2.864662  2.812500  2.913462  2.609804  2.770936  2.897059  2.842105
#
# [5 rows x 22 columns]

# %%
df_pivot.rename(columns={'movieid': 'movieid'}, inplace=True)

# %%
df_pivot.head()
# Out:
#      movieid rating                                                    \
# year           1995      1996      1997      1998      1999      2000
# 0          1    0.0  4.132270  3.875424  3.885799  3.974688  4.142609
# 1          2    0.0  3.564570  3.457698  3.263158  3.139094  3.146533
# 2          3    0.0  3.413843  3.291299  3.102990  2.930788  3.024691
# 3          4    0.0  3.030162  3.057803  2.590909  2.710000  2.744382
# 4          5    0.0  3.338714  3.114710  3.090909  3.070922  2.934859
#
#                                     ...                                \
# year      2001      2002      2003  ...      2006      2007      2008
# 0     4.117698  4.047855  4.004680  ...  3.680774  3.672973  3.740781
# 1     3.136856  3.077821  2.956271  ...  2.876154  2.923704  3.059659
# 2     3.204023  3.021552  2.957346  ...  2.758454  2.990909  3.112245
# 3     2.755906  2.836735  2.564103  ...  2.531250  2.310811  2.523810
# 4     3.100000  3.004651  2.803867  ...  2.765337  2.633333  2.725849
#
#
# year      2009      2010      2011      2012      2013      2014      2015
# 0     3.766777  3.856772  3.861689  3.931421  3.946274  3.954945  3.860412
# 1     3.044865  3.159884  3.178733  3.201903  3.266667  3.346552  3.128049
# 2     3.102837  2.986364  3.051724  2.799451  3.064103  3.048387  2.854167
# 3     2.500000  2.833333  2.944444  2.545455  3.187500  2.357143  2.000000
# 4     2.864662  2.812500  2.913462  2.609804  2.770936  2.897059  2.842105
#
# [5 rows x 22 columns]

# %%
columns = [col[1] if isinstance(col, tuple) else col for col in df_pivot.columns]
columns[0] = "movieid"
df_pivot.columns = columns

# %%
year_cols = [c for c in df_pivot.columns if isinstance(c, str) and c.isdigit()]
for col in year_cols:
    df_pivot[col] = pd.to_numeric(df_pivot[col], errors='coerce')

# %%
df_pivot.head()
# Out:
#    movieid  1995      1996      1997      1998      1999      2000      2001  \
# 0        1   0.0  4.132270  3.875424  3.885799  3.974688  4.142609  4.117698
# 1        2   0.0  3.564570  3.457698  3.263158  3.139094  3.146533  3.136856
# 2        3   0.0  3.413843  3.291299  3.102990  2.930788  3.024691  3.204023
# 3        4   0.0  3.030162  3.057803  2.590909  2.710000  2.744382  2.755906
# 4        5   0.0  3.338714  3.114710  3.090909  3.070922  2.934859  3.100000
#
#        2002      2003  ...      2006      2007      2008      2009      2010  \
# 0  4.047855  4.004680  ...  3.680774  3.672973  3.740781  3.766777  3.856772
# 1  3.077821  2.956271  ...  2.876154  2.923704  3.059659  3.044865  3.159884
# 2  3.021552  2.957346  ...  2.758454  2.990909  3.112245  3.102837  2.986364
# 3  2.836735  2.564103  ...  2.531250  2.310811  2.523810  2.500000  2.833333
# 4  3.004651  2.803867  ...  2.765337  2.633333  2.725849  2.864662  2.812500
#
#        2011      2012      2013      2014      2015
# 0  3.861689  3.931421  3.946274  3.954945  3.860412
# 1  3.178733  3.201903  3.266667  3.346552  3.128049
# 2  3.051724  2.799451  3.064103  3.048387  2.854167
# 3  2.944444  2.545455  3.187500  2.357143  2.000000
# 4  2.913462  2.609804  2.770936  2.897059  2.842105
#
# [5 rows x 22 columns]

# %%
df_pivot.reset_index()
# Out:
#        index  movieid  1995      1996      1997      1998      1999      2000  \
# 0          0        1   0.0  4.132270  3.875424  3.885799  3.974688  4.142609
# 1          1        2   0.0  3.564570  3.457698  3.263158  3.139094  3.146533
# 2          2        3   0.0  3.413843  3.291299  3.102990  2.930788  3.024691
# 3          3        4   0.0  3.030162  3.057803  2.590909  2.710000  2.744382
# 4          4        5   0.0  3.338714  3.114710  3.090909  3.070922  2.934859
# ...      ...      ...   ...       ...       ...       ...       ...       ...
# 26739  26739   131254   0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 26740  26740   131256   0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 26741  26741   131258   0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 26742  26742   131260   0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 26743  26743   131262   0.0  0.000000  0.000000  0.000000  0.000000  0.000000
#
#            2001      2002  ...      2006      2007      2008      2009  \
# 0      4.117698  4.047855  ...  3.680774  3.672973  3.740781  3.766777
# 1      3.136856  3.077821  ...  2.876154  2.923704  3.059659  3.044865
# 2      3.204023  3.021552  ...  2.758454  2.990909  3.112245  3.102837
# 3      2.755906  2.836735  ...  2.531250  2.310811  2.523810  2.500000
# 4      3.100000  3.004651  ...  2.765337  2.633333  2.725849  2.864662
# ...         ...       ...  ...       ...       ...       ...       ...
# 26739  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 26740  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 26741  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 26742  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 26743  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
#
#            2010      2011      2012      2013      2014      2015
# 0      3.856772  3.861689  3.931421  3.946274  3.954945  3.860412
# 1      3.159884  3.178733  3.201903  3.266667  3.346552  3.128049
# 2      2.986364  3.051724  2.799451  3.064103  3.048387  2.854167
# 3      2.833333  2.944444  2.545455  3.187500  2.357143  2.000000
# 4      2.812500  2.913462  2.609804  2.770936  2.897059  2.842105
# ...         ...       ...       ...       ...       ...       ...
# 26739  0.000000  0.000000  0.000000  0.000000  0.000000  4.000000
# 26740  0.000000  0.000000  0.000000  0.000000  0.000000  4.000000
# 26741  0.000000  0.000000  0.000000  0.000000  0.000000  2.500000
# 26742  0.000000  0.000000  0.000000  0.000000  0.000000  3.000000
# 26743  0.000000  0.000000  0.000000  0.000000  0.000000  4.000000
#
# [26744 rows x 23 columns]

# %%
df_pivot.set_index("movieid", drop=True)
# Out:
#          1995      1996      1997      1998      1999      2000      2001  \
# movieid
# 1         0.0  4.132270  3.875424  3.885799  3.974688  4.142609  4.117698
# 2         0.0  3.564570  3.457698  3.263158  3.139094  3.146533  3.136856
# 3         0.0  3.413843  3.291299  3.102990  2.930788  3.024691  3.204023
# 4         0.0  3.030162  3.057803  2.590909  2.710000  2.744382  2.755906
# 5         0.0  3.338714  3.114710  3.090909  3.070922  2.934859  3.100000
# ...       ...       ...       ...       ...       ...       ...       ...
# 131254    0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 131256    0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 131258    0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 131260    0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 131262    0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#              2002      2003      2004  ...      2006      2007      2008  \
# movieid                                ...
# 1        4.047855  4.004680  3.863380  ...  3.680774  3.672973  3.740781
# 2        3.077821  2.956271  2.887043  ...  2.876154  2.923704  3.059659
# 3        3.021552  2.957346  2.920536  ...  2.758454  2.990909  3.112245
# 4        2.836735  2.564103  2.585859  ...  2.531250  2.310811  2.523810
# 5        3.004651  2.803867  2.797483  ...  2.765337  2.633333  2.725849
# ...           ...       ...       ...  ...       ...       ...       ...
# 131254   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 131256   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 131258   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 131260   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 131262   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
#
#              2009      2010      2011      2012      2013      2014      2015
# movieid
# 1        3.766777  3.856772  3.861689  3.931421  3.946274  3.954945  3.860412
# 2        3.044865  3.159884  3.178733  3.201903  3.266667  3.346552  3.128049
# 3        3.102837  2.986364  3.051724  2.799451  3.064103  3.048387  2.854167
# 4        2.500000  2.833333  2.944444  2.545455  3.187500  2.357143  2.000000
# 5        2.864662  2.812500  2.913462  2.609804  2.770936  2.897059  2.842105
# ...           ...       ...       ...       ...       ...       ...       ...
# 131254   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  4.000000
# 131256   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  4.000000
# 131258   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  2.500000
# 131260   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  3.000000
# 131262   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  4.000000
#
# [26744 rows x 21 columns]

# %%
# Guardado de tabla de dimension

df_pivot.to_csv(r"../data/partial_rating_year.csv")

# %% [markdown]
# # DATA OPCION 3
# Promedio y conteo agrupado por movieid, userid, year, month
# Resultado -> archivo tipo tabla de dimension

# %% [markdown]
# ### Esto es para una tabla de dimensión `d_rating`
# Contendra la pelicula agrupado por usuario, año y por mes

# %%
# Obtenemos el rating promedio por pelicula, año y mes
grupo = rating.groupby(["movieid","userid", "year","month"])["rating"]
rating_movies_year_month_promedio = grupo.mean()
rating_movies_year_month_conteo = grupo.count()

# %%
# Deberia ser una table dimension
rating_movies_year_month_promedio.head()
# Out:
# movieid  userid  year  month
# 1        3       1999  12       4.0
#          6       1997  3        5.0
#          8       1996  6        4.0
#          10      1999  11       4.0
#          11      2009  1        4.5
# Name: rating, dtype: float64

# %%
rating_movies_year_month_conteo.head()
# Out:
# movieid  userid  year  month
# 1        3       1999  12       1
#          6       1997  3        1
#          8       1996  6        1
#          10      1999  11       1
#          11      2009  1        1
# Name: rating, dtype: int64

# %%
# union de promeido y conteo
dim_rating = pd.merge(rating_movies_year_month_promedio, rating_movies_year_month_conteo, on=["movieid","userid", "year","month"], how="left")

# %%
dim_rating.head()
# Out:
#                            rating_x  rating_y
# movieid userid year month
# 1       3      1999 12          4.0         1
#         6      1997 3           5.0         1
#         8      1996 6           4.0         1
#         10     1999 11          4.0         1
#         11     2009 1           4.5         1

# %%
# renombrar columnas
dim_rating = dim_rating.rename(
    columns={
        "rating_x": "promedio",
        "rating_y": "conteo"
    }
)

# %%
dim_rating.reset_index(inplace=True)

# %%
dim_rating
# Out:
#           movieid  userid  year  month  promedio  conteo
# 0               1       3  1999     12       4.0       1
# 1               1       6  1997      3       5.0       1
# 2               1       8  1996      6       4.0       1
# 3               1      10  1999     11       4.0       1
# 4               1      11  2009      1       4.5       1
# ...           ...     ...   ...    ...       ...     ...
# 20000258   131254   79570  2015      3       4.0       1
# 20000259   131256   79570  2015      3       4.0       1
# 20000260   131258   28906  2015      3       2.5       1
# 20000261   131260   65409  2015      3       3.0       1
# 20000262   131262  133047  2015      3       4.0       1
#
# [20000263 rows x 6 columns]

# %%
dim_rating.head()
# Out:
#    movieid  userid  year  month  promedio  conteo
# 0        1       3  1999     12       4.0       1
# 1        1       6  1997      3       5.0       1
# 2        1       8  1996      6       4.0       1
# 3        1      10  1999     11       4.0       1
# 4        1      11  2009      1       4.5       1

# %%
dim_rating["ratingid"] = range(1, len(dim_rating) + 1)

# %%
dim_rating.set_index("ratingid", inplace=True)

# %%
dim_rating.head()
# Out:
#           movieid  userid  year  month  promedio  conteo
# ratingid
# 1               1       3  1999     12       4.0       1
# 2               1       6  1997      3       5.0       1
# 3               1       8  1996      6       4.0       1
# 4               1      10  1999     11       4.0       1
# 5               1      11  2009      1       4.5       1

# %%
# Guardado de tabla de dimension
dim_rating.to_csv(r"../data/d_rating.csv")
