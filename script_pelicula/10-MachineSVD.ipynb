# %% [markdown]
# # Singular Value Decomposition (SVD)

# %%
import pandas as pd
import numpy as np
from numpy.linalg import svd

# %%
# Cargar datos limpios
ratings_original = pd.read_csv(r"../data/process/clean_rating.csv")

# %%
ratings_original
# Out:
#         userid  movieid  rating            timestamp
# 0           31        1     3.0  2015-02-23 23:18:07
# 1           31      110     5.0  2015-02-23 23:17:53
# 2           31      260     5.0  2015-02-23 23:17:13
# 3           31      364     3.0  2015-02-25 06:13:27
# 4           31      527     0.5  2015-02-23 23:19:58
# ...        ...      ...     ...                  ...
# 283881  138414   100163     3.0  2015-03-03 21:49:43
# 283882  138414   102720     3.5  2015-01-18 07:38:37
# 283883  138414   112183     5.0  2015-02-21 17:23:08
# 283884  138414   115617     4.0  2015-01-15 09:19:49
# 283885  138414   117851     3.5  2015-02-24 07:25:30
#
# [283886 rows x 4 columns]

# %%
ratings_original.shape
# Out:
# (283886, 4)

# %%
movies = pd.read_csv(r"../data/process/movie_perfil_contenido.csv",
        # usecols = ["movieid", "title"]
)
movies.shape
# Out:
# (27278, 48)

# %%
df = pd.merge(ratings_original, movies, on='movieid')

# %%
df.head()
# Out:
#    userid  movieid  rating            timestamp  \
# 0      31        1     3.0  2015-02-23 23:18:07
# 1      31      110     5.0  2015-02-23 23:17:53
# 2      31      260     5.0  2015-02-23 23:17:13
# 3      31      364     3.0  2015-02-25 06:13:27
# 4      31      527     0.5  2015-02-23 23:19:58
#
#                                      title  \
# 0                         Toy Story (1995)
# 1                        Braveheart (1995)
# 2  Star Wars Episode IV  A New Hope (1977)
# 3                    Lion King, The (1994)
# 4                  Schindler's List (1993)
#
#                                             genres  no_genres_listed  Action  \
# 0      Adventure|Animation|Children|Comedy|Fantasy                 0       0
# 1                                 Action|Drama|War                 0       1
# 2                          Action|Adventure|Sci-Fi                 0       1
# 3  Adventure|Animation|Children|Drama|Musical|IMAX                 0       0
# 4                                        Drama|War                 0       0
#
#    Adventure  Animation  ...      2008      2009      2010      2011  \
# 0          1          1  ...  3.740781  3.766777  3.856772  3.861689
# 1          0          0  ...  3.890887  3.851640  3.847527  3.849012
# 2          1          0  ...  4.050584  4.041898  4.084775  4.097885
# 3          1          1  ...  3.729811  3.819801  3.891230  3.917090
# 4          0          0  ...  4.160721  4.121274  4.159131  4.116312
#
#        2012      2013      2014      2015  \
# 0  3.931421  3.946274  3.954945  3.860412
# 1  3.869754  3.869778  3.820526  3.809346
# 2  4.096226  4.149308  4.052098  3.897613
# 3  3.959759  3.975145  3.930285  3.913725
# 4  4.136686  4.143459  4.108263  3.963446
#
#                                                  tag  tmdbid
# 0  Watched, computeranimation, Disneyanimatedfeat...   862.0
# 1  drama, historical, Medieval, melgibson, Nudity...   197.0
# 2  1970s, fantasy, scifi, epic, exciting, galacti...    11.0
# 3  comingofage, Disneyanimatedfeature, hereditary...  8587.0
# 4  blackandwhite, hitler, WorldWarII, Holocaust, ...   424.0
#
# [5 rows x 51 columns]

# %%
n_users = df['userid'].nunique()
n_movies = df['movieid'].nunique()

# %%
print(f"Numero de users: {n_users}")
print(f"Numero de Peliculas: {n_movies}")
print(f"Total ratings: {len(df)}")
# Out:
# Numero de users: 3903
# Numero de Peliculas: 14639
# Total ratings: 283886

# %%
user_item_matrix = df.pivot_table(index='userid', columns='movieid', values='rating').fillna(0)

# %%
print("Matrix:", user_item_matrix.shape)
# Out:
# Matrix: (3903, 14639)

# %%
R = user_item_matrix.to_numpy()

# %%
U, sigma, Vt = svd(R, full_matrices=False)
print(f"Shapes -> U: {U.shape}, Sigma: {sigma.shape}, Vt: {Vt.shape}")
# Out:
# Shapes -> U: (3903, 3903), Sigma: (3903,), Vt: (3903, 14639)

# %%
k = 50
sigma_k = np.diag(sigma[:k])

R_approx = np.dot(np.dot(U[:, :k], sigma_k), Vt[:k, :])
R_pred_df = pd.DataFrame(R_approx, 
                        index=user_item_matrix.index, 
                        columns=user_item_matrix.columns)

# %%
R_pred_df.head()
# Out:
# movieid    1         2         3         4         5         6         7       \
# userid
# 31       2.393364  1.019678 -0.137438 -0.064030 -0.101425 -0.721240 -0.255042
# 96       0.299233  0.069756 -0.021975 -0.019778 -0.032301  0.148120 -0.062171
# 176      0.714557  0.199338  0.023719  0.016660  0.082528  0.212068  0.032570
# 215      0.054778  0.051330  0.010721 -0.003024 -0.002939  0.030169  0.009479
# 260      1.469242  0.560003  0.064146  0.019282  0.102312  0.017921  0.146009
#
# movieid    8         9         10      ...    131241    131243    131248  \
# userid                                 ...
# 31      -0.030826  0.004921  0.084256  ...  0.076120  0.076120  0.076120
# 96      -0.004031 -0.004191  0.047577  ...  0.008369  0.008369  0.008369
# 176      0.016874 -0.016514  0.072500  ... -0.002270 -0.002270 -0.002270
# 215      0.002904 -0.002172  0.012541  ...  0.005297  0.005297  0.005297
# 260     -0.010838 -0.011901  0.154965  ... -0.008552 -0.008552 -0.008552
#
# movieid    131250    131252    131254    131256    131258    131260    131262
# userid
# 31       0.076120  0.076120  0.076120  0.076120 -0.003037 -0.001720 -0.004253
# 96       0.008369  0.008369  0.008369  0.008369 -0.000932 -0.001973  0.000581
# 176     -0.002270 -0.002270 -0.002270 -0.002270 -0.000056 -0.001319 -0.000709
# 215      0.005297  0.005297  0.005297  0.005297  0.000189 -0.000181 -0.000026
# 260     -0.008552 -0.008552 -0.008552 -0.008552 -0.001949  0.004382  0.004300
#
# [5 rows x 14639 columns]

# %%
user_id = 31

# Original ratings and predictions
user_ratings = user_item_matrix.loc[user_id]
user_predictions = R_pred_df.loc[user_id]

# Recommend top 10 unrated movies
unrated = user_ratings[user_ratings == 0]
recommendations = user_predictions[unrated.index].sort_values(ascending=False).head(10)
recommendations.reset_index( inplace=False )
#recommendations

# rdf = pd.merge(recommendations, movies, left_on="movieid", right_on="movieid", how="left")
rdf = pd.merge(recommendations, movies, on="movieid", how="left")
rdf.head()
# Out:
#    movieid        31                                     title  \
# 0    78499  3.244044                        Toy Story 3 (2010)
# 1   111362  3.199614           XMen Days of Future Past (2014)
# 2    91542  2.785006  Sherlock Holmes A Game of Shadows (2011)
# 3    56174  2.656042                        I Am Legend (2007)
# 4     8644  2.623568                           I, Robot (2004)
#
#                                              genres  no_genres_listed  Action  \
# 0  Adventure|Animation|Children|Comedy|Fantasy|IMAX                 0       0
# 1                           Action|Adventure|Sci-Fi                 0       1
# 2    Action|Adventure|Comedy|Crime|Mystery|Thriller                 0       1
# 3                Action|Horror|Sci-Fi|Thriller|IMAX                 0       1
# 4                  Action|Adventure|Sci-Fi|Thriller                 0       1
#
#    Adventure  Animation  Children  Comedy  ...      2008      2009      2010  \
# 0          1          1         1       1  ...  0.000000  0.000000  4.142544
# 1          1          0         0       0  ...  0.000000  0.000000  0.000000
# 2          1          0         0       1  ...  0.000000  0.000000  0.000000
# 3          0          0         0       0  ...  3.476411  3.442442  3.490771
# 4          1          0         0       0  ...  3.471572  3.407767  3.438816
#
#        2011      2012      2013      2014      2015  \
# 0  4.012645  3.993615  3.965144  3.925974  3.889976
# 1  0.000000  0.000000  0.000000  3.846614  3.780189
# 2  3.590909  3.771689  3.874034  3.834630  3.655039
# 3  3.556999  3.553996  3.605178  3.422892  3.475884
# 4  3.555469  3.541331  3.558201  3.462585  3.373938
#
#                                                  tag    tmdbid
# 0  tense, Alivetoys, adventure, animation, bitter...   10193.0
# 1  JamesMcAvoy, JenniferLawrence, Marvel, Patrick...  127585.0
# 2  adaptedfrombookseries, animaldog, animaldonkey...   58574.0
# 3  adaptedfrombook, anotheradaptationofIamLegend,...    6479.0
# 4  artificialintelligence, futuristic, scifi, and...    2048.0
#
# [5 rows x 49 columns]
